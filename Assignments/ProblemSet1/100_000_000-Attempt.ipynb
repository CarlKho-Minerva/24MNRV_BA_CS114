# %%
# Took 5 minutes
# Run the simulation for 1,000,000 trials
print(simulate_license_plates(100_000_000))
# Out:
# Total possible license plate arrangements: 6.4310e+26
# Favorable outcomes for no repeated characters: 19656000
# Favorable outcomes for palindromes: 67600
# First five generated plates: ['EH148BT', 'WG316TW', 'JL463VH', 'AM313SK', 'UV452ZD']
# Count of plates with no repeated characters: 56530649
# Count of palindrome plates: 14820
# ...
